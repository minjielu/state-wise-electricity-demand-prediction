# %%
import requests as rq
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from collections import Counter
import statsmodels.api as sm
from sklearn.feature_extraction import DictVectorizer as DV
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load and process the electricity data

# %%
end = '20190918T23-05'
start = '20130918T23-05'
key = '8a6315646d5695061696c71a041c42c0'
series_id = 'EBA.TEX-ALL.D.HL'
data = rq.get("http://api.eia.gov/series/?api_key={}&series_id={}&start={}&end={}".format(key, series_id, start, end))
hourly_demand = data.json()['series'][0]['data']
electricity_demand = pd.DataFrame(hourly_demand, columns=['datetime','usage'])

electricity_demand['datetime'] = pd.to_datetime(electricity_demand['datetime'], format='%Y%m%dT%H-%M')
electricity_demand['time'] = electricity_demand['datetime'].apply(lambda x:x.hour)
electricity_demand['month'] = electricity_demand['datetime'].apply(lambda x:x.month)
electricity_demand['weekday'] = electricity_demand['datetime'].apply(lambda x:x.weekday())
electricity_demand['year'] = electricity_demand['datetime'].apply(lambda x:x.year)
electricity_demand['day'] = electricity_demand['datetime'].apply(lambda x:x.day)

# %% [markdown]
# ## Load and process the weather data

# %%
def round_time(date_time):
    minute = date_time.minute
    if minute > 30:
        return date_time+timedelta(hours=1)
    else:
        return date_time

# %%
houston = pd.read_csv('electricity_data/temperatures/Houston.csv', index_col=False)
# Out:
# /Users/minjielu/anaconda3/envs/Renaissance/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (19,25,26,27,28,29,35,36,41,42,43,48,49,51,53,56,58,59,60,61,63,77,82,114,117,119) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.options.display.max_columns = 200
houston.head(2)
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE  AWND  \
# 0  72242712975  2015-07-01T00:53:00       FM-15       7   NaN
# 1  72242712975  2015-07-01T01:53:00       FM-15       7   NaN
#
#    BackupDirection  BackupDistance  BackupDistanceUnit  BackupElements  \
# 0              NaN             NaN                 NaN             NaN
# 1              NaN             NaN                 NaN             NaN
#
#    BackupElevation  BackupElevationUnit  BackupEquipment  BackupLatitude  \
# 0              NaN                  NaN              NaN             NaN
# 1              NaN                  NaN              NaN             NaN
#
#    BackupLongitude  BackupName  CDSD  CLDD  DSNW  \
# 0              NaN         NaN   NaN   NaN   NaN
# 1              NaN         NaN   NaN   NaN   NaN
#
#    DailyAverageDewPointTemperature DailyAverageDryBulbTemperature  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
#
#    DailyAverageRelativeHumidity  DailyAverageSeaLevelPressure  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    DailyAverageStationPressure  DailyAverageWetBulbTemperature  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
#
#    DailyAverageWindSpeed DailyCoolingDegreeDays  \
# 0                    NaN                    NaN
# 1                    NaN                    NaN
#
#   DailyDepartureFromNormalAverageTemperature DailyHeatingDegreeDays  \
# 0                                        NaN                    NaN
# 1                                        NaN                    NaN
#
#   DailyMaximumDryBulbTemperature DailyMinimumDryBulbTemperature  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
#
#   DailyPeakWindDirection DailyPeakWindSpeed DailyPrecipitation  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
#
#    DailySnowDepth  DailySnowfall DailySustainedWindDirection  \
# 0             NaN            NaN                         NaN
# 1             NaN            NaN                         NaN
#
#   DailySustainedWindSpeed DailyWeather  HDSD  HTDD  HeavyFog  \
# 0                     NaN          NaN   NaN   NaN       NaN
# 1                     NaN          NaN   NaN   NaN       NaN
#
#   HourlyAltimeterSetting HourlyDewPointTemperature HourlyDryBulbTemperature  \
# 0                  30.05                        71                       74
# 1                  30.06                        71                       74
#
#   HourlyPrecipitation HourlyPresentWeatherType  HourlyPressureChange  \
# 0                0.00                      NaN                   NaN
# 1                0.00                      NaN                   NaN
#
#    HourlyPressureTendency HourlyRelativeHumidity HourlySeaLevelPressure  \
# 0                     NaN                     91                  30.05
# 1                     NaN                     91                  30.06
#
#   HourlySkyConditions HourlyStationPressure HourlyVisibility  \
# 0              CLR:00                 30.00            10.00
# 1              CLR:00                 30.01            10.00
#
#   HourlyWetBulbTemperature HourlyWindDirection  HourlyWindGustSpeed  \
# 0                       72                 000                  NaN
# 1                       72                 000                  NaN
#
#   HourlyWindSpeed  MonthlyAverageRH MonthlyDaysWithGT001Precip  \
# 0               0               NaN                        NaN
# 1               0               NaN                        NaN
#
#   MonthlyDaysWithGT010Precip MonthlyDaysWithGT32Temp MonthlyDaysWithGT90Temp  \
# 0                        NaN                     NaN                     NaN
# 1                        NaN                     NaN                     NaN
#
#    MonthlyDaysWithLT0Temp MonthlyDaysWithLT32Temp  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
#
#    MonthlyDepartureFromNormalAverageTemperature  \
# 0                                           NaN
# 1                                           NaN
#
#    MonthlyDepartureFromNormalCoolingDegreeDays  \
# 0                                          NaN
# 1                                          NaN
#
#    MonthlyDepartureFromNormalHeatingDegreeDays  \
# 0                                          NaN
# 1                                          NaN
#
#    MonthlyDepartureFromNormalMaximumTemperature  \
# 0                                           NaN
# 1                                           NaN
#
#    MonthlyDepartureFromNormalMinimumTemperature  \
# 0                                           NaN
# 1                                           NaN
#
#   MonthlyDepartureFromNormalPrecipitation  MonthlyDewpointTemperature  \
# 0                                     NaN                         NaN
# 1                                     NaN                         NaN
#
#   MonthlyGreatestPrecip MonthlyGreatestPrecipDate  MonthlyGreatestSnowDepth  \
# 0                   NaN                       NaN                       NaN
# 1                   NaN                       NaN                       NaN
#
#    MonthlyGreatestSnowDepthDate  MonthlyGreatestSnowfall  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
#
#    MonthlyGreatestSnowfallDate MonthlyMaxSeaLevelPressureValue  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
#
#    MonthlyMaxSeaLevelPressureValueDate  MonthlyMaxSeaLevelPressureValueTime  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
#
#    MonthlyMaximumTemperature  MonthlyMeanTemperature  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
#
#   MonthlyMinSeaLevelPressureValue  MonthlyMinSeaLevelPressureValueDate  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
#
#    MonthlyMinSeaLevelPressureValueTime  MonthlyMinimumTemperature  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
#
#    MonthlySeaLevelPressure  MonthlyStationPressure  \
# 0                      NaN                     NaN
# 1                      NaN                     NaN
#
#   MonthlyTotalLiquidPrecipitation  MonthlyTotalSnowfall  MonthlyWetBulb  \
# 0                             NaN                   NaN             NaN
# 1                             NaN                   NaN             NaN
#
#    NormalsCoolingDegreeDay  NormalsHeatingDegreeDay  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
#
#                                                  REM REPORT_TYPE.1  SOURCE.1  \
# 0  MET09007/01/15 00:53:02 METAR KLVJ 010653Z 000...         FM-15         7
# 1  MET09007/01/15 01:53:02 METAR KLVJ 010753Z 000...         FM-15         7
#
#   ShortDurationEndDate005 ShortDurationEndDate010 ShortDurationEndDate015  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
#
#   ShortDurationEndDate020 ShortDurationEndDate030 ShortDurationEndDate045  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
#
#   ShortDurationEndDate060 ShortDurationEndDate080 ShortDurationEndDate100  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
#
#   ShortDurationEndDate120 ShortDurationEndDate150 ShortDurationEndDate180  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
#
#    ShortDurationPrecipitationValue005  ShortDurationPrecipitationValue010  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
#
#    ShortDurationPrecipitationValue015  ShortDurationPrecipitationValue020  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
#
#    ShortDurationPrecipitationValue030  ShortDurationPrecipitationValue045  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
#
#   ShortDurationPrecipitationValue060  ShortDurationPrecipitationValue080  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
#
#    ShortDurationPrecipitationValue100 ShortDurationPrecipitationValue120  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
#
#    ShortDurationPrecipitationValue150 ShortDurationPrecipitationValue180  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
#
#    Sunrise  Sunset  TStorms WindEquipmentChangeDate
# 0      NaN     NaN      NaN              2007-06-06
# 1      NaN     NaN      NaN              2007-06-06

# %%
weather_columns = ['DATE', 'DailyPrecipitation','DailySnowDepth','DailySnowfall','DailyWeather','HDSD','HTDD','HeavyFog'
,'HourlyPrecipitation','HourlyPresentWeatherType','HourlyRelativeHumidity','HourlySkyConditions',
'HourlyVisibility']
# DailySnowDepth might be useful for the Northwest region. 
key_weather_columns = ['DailyWeather', 'HourlyPrecipitation','HourlyPresentWeatherType','HourlySkyConditions']

houston = houston[weather_columns]
key_houston = houston[key_weather_columns]

# %%
houston.head(10)
# Out:
#                   DATE DailyPrecipitation  DailySnowDepth  DailySnowfall  \
# 0  2015-07-01T00:53:00                NaN             NaN            NaN
# 1  2015-07-01T01:53:00                NaN             NaN            NaN
# 2  2015-07-01T02:53:00                NaN             NaN            NaN
# 3  2015-07-01T03:53:00                NaN             NaN            NaN
# 4  2015-07-01T04:53:00                NaN             NaN            NaN
# 5  2015-07-01T05:53:00                NaN             NaN            NaN
# 6  2015-07-01T06:53:00                NaN             NaN            NaN
# 7  2015-07-01T07:53:00                NaN             NaN            NaN
# 8  2015-07-01T08:53:00                NaN             NaN            NaN
# 9  2015-07-01T09:09:00                NaN             NaN            NaN
#
#   DailyWeather  HDSD  HTDD  HeavyFog HourlyPrecipitation  \
# 0          NaN   NaN   NaN       NaN                0.00
# 1          NaN   NaN   NaN       NaN                0.00
# 2          NaN   NaN   NaN       NaN                   T
# 3          NaN   NaN   NaN       NaN                   T
# 4          NaN   NaN   NaN       NaN                0.00
# 5          NaN   NaN   NaN       NaN                0.00
# 6          NaN   NaN   NaN       NaN                0.00
# 7          NaN   NaN   NaN       NaN                0.00
# 8          NaN   NaN   NaN       NaN                0.00
# 9          NaN   NaN   NaN       NaN                0.10
#
#   HourlyPresentWeatherType HourlyRelativeHumidity  \
# 0                      NaN                     91
# 1                      NaN                     91
# 2                      NaN                     94
# 3                      NaN                     94
# 4                      NaN                     90
# 5                      NaN                     91
# 6                      NaN                     88
# 7                      NaN                     79
# 8                      NaN                     77
# 9             +RA:02 |RA |                     82
#
#              HourlySkyConditions HourlyVisibility
# 0                         CLR:00            10.00
# 1                         CLR:00            10.00
# 2                      FEW:02 90            10.00
# 3                         CLR:00            10.00
# 4                         CLR:00            10.00
# 5                         CLR:00            10.00
# 6                         CLR:00            10.00
# 7                         CLR:00            10.00
# 8                      FEW:02 17            10.00
# 9  SCT:04 19 BKN:07 34 BKN:07 43             1.75

# %%
# Round the date info
houston['datetime'] = pd.to_datetime(houston['DATE'], format='%Y-%m-%dT%H:%M:%S')
houston['date'] = houston['datetime'].apply(lambda date_time: round_time(date_time))
houston['time'] = houston['date'].apply(lambda x:x.hour)
houston['month'] = houston['date'].apply(lambda x:x.month)
houston['day'] = houston['date'].apply(lambda x:x.day)
# weather['weekday'] = weather['date'].apply(lambda x:x.weekday())
houston['year'] = houston['date'].apply(lambda x:x.year)

# %%
match_columns = ['year', 'month', 'day', 'time']
df_joined = electricity_demand.merge(houston, how='inner', left_on=match_columns, right_on=match_columns)

# %%
# Different kinds of weathers.
weather_types = []

for ind, item in houston['HourlyPresentWeatherType'].iteritems():
    if not pd.isna(item):
        au = item.split('|')[0]
        for code in au.split(' '):
            weather_types.append(code)
                
weather_types = Counter(weather_types)

# %%
weather_types
# Out:
# Counter({'': 21312,
#          '*': 12,
#          '+RA:02': 2612,
#          '-FZ:8': 27,
#          '-RA:02': 6334,
#          '-SN:03': 70,
#          'BR:1': 13490,
#          'FG:2': 816,
#          'FZ:8': 10,
#          'HZ:7': 896,
#          'RA:02': 2003,
#          'SN:03': 1,
#          'SQ:2': 13,
#          'TS:7': 2407,
#          'UP:09': 44,
#          'VCTS:7': 2503,
#          's': 37})

# %%
def processing_au_code(code):
    if pd.isna(code):
        return {'SUN':1}
    else:
        au = code.split('|')[0]
        weathers = {}
        for code in au.split(' '):
            if code != '':
                weathers[code] = 1
        return weathers

# %%
weather_encoded = df_joined['HourlyPresentWeatherType'].apply(processing_au_code).values

# %%
vectorizer = DV(sparse=False)
weather_vectorized = vectorizer.fit_transform(weather_encoded)

# %%
usage = df_joined['usage'].values

# %%
lr_model = LinearRegression()
lr_model.fit(weather_vectorized, usage)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr_model.coef_
# Out:
# array([-5.16397375e+02,  1.05974694e+03,  7.59432321e+03,  5.17230749e+00,
#         1.39635788e+04, -5.54434463e+03, -6.74275719e+03,  1.13564648e+04,
#        -9.70102562e+02,  9.95953468e+02,  8.98639501e+03,  4.62544780e+03,
#         5.64868588e+02,  5.59843748e+03,  1.30094520e+04,  4.95926080e+03,
#         5.87395882e+03])

# %%
X = sm.add_constant(weather_vectorized)
sm_lr_model = sm.OLS(usage, X)
res = sm_lr_model.fit()
print(res.conf_int(0.01))
