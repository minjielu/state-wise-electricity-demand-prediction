# %%
import requests as rq
from pymongo import MongoClient
import pandas as pd
from datetime import datetime, timedelta
from sklearn import preprocessing
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor as RF
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from tqdm import tqdm_notebook
from sklearn.linear_model import LinearRegression as LR 
from sklearn.model_selection import GridSearchCV
import warnings
import os

warnings.filterwarnings('ignore')

# %% [markdown]
# # Get the electricity demand data

# %%
end = '20190918T23-05'
start = '20130918T23-05'
key = '8a6315646d5695061696c71a041c42c0'
# series_id = 'EBA.TEX-ALL.D.HL'
series_id = 'EBA.NW-ALL.D.HL'
data = rq.get("http://api.eia.gov/series/?api_key={}&series_id={}&start={}&end={}".format(key, series_id, start, end))

# %%
hourly_demand = data.json()['series'][0]['data']

# %%
electricity_demand = pd.DataFrame(hourly_demand, columns=['datetime','usage'])
electricity_demand.to_csv('electricity_data/electricity_demand.csv')

# %%
electricity_demand.head(1)
# Out:
#          datetime  usage
# 0  20190918T22-06  40510

# %%
electricity_demand.tail(1)
# Out:
#              datetime  usage
# 36981  20150701T01-06  12775

# %%
electricity_demand['datetime'] = pd.to_datetime(electricity_demand['datetime'], format='%Y%m%dT%H-%M')
electricity_demand['time'] = electricity_demand['datetime'].apply(lambda x:x.hour)
electricity_demand['month'] = electricity_demand['datetime'].apply(lambda x:x.month)
electricity_demand['weekday'] = electricity_demand['datetime'].apply(lambda x:x.weekday())
electricity_demand['year'] = electricity_demand['datetime'].apply(lambda x:x.year)
electricity_demand['day'] = electricity_demand['datetime'].apply(lambda x:x.day)

# %%
# Normalize the usage
electricity_demand['normalized_usage'] = preprocessing.MinMaxScaler().fit_transform(electricity_demand['usage'].values.reshape(-1,1))
electricity_demand.head(3)
# Out:
#              datetime  usage  time  month  weekday  year  day  \
# 0 2019-09-18 22:06:00  40510    22      9        2  2019   18
# 1 2019-09-18 21:06:00  41726    21      9        2  2019   18
# 2 2019-09-18 20:06:00  41714    20      9        2  2019   18
#
#    normalized_usage
# 0          0.601575
# 1          0.627950
# 2          0.627690

# %%
electricity_demand.tail(2)
# Out:
#                  datetime  usage  time  month  weekday  year  day  \
# 36980 2015-07-01 02:06:00  34914     2      7        2  2015    1
# 36981 2015-07-01 01:06:00  12775     1      7        2  2015    1
#
#        normalized_usage
# 36980          0.480197
# 36981          0.000000

# %% [markdown]
# # Get the hourly weather data

# %%
#weather_2013 = pd.read_csv('electricity_data/hourly_temperature_2013.csv')
#weather_2015 = pd.read_csv('electricity_data/hourly_temperature_2015.csv')
#weather_2016 = pd.read_csv('electricity_data/hourly_temperature_2016.csv')
#weather = pd.concat([weather_2013, weather_2015, weather_2016])

# Other weather data.
# temp_dir = 'electricity_data/temperatures/'
temp_dir = 'electricity_data/NW/'
# stations = [72243012960, 72259003927, 72253012921]
stations = []
weather = pd.DataFrame()

for file in os.listdir(temp_dir):
    if file.endswith('.csv'):
        temp_df = pd.read_csv(temp_dir+file)
        stations.append(temp_df.head(1)['STATION'].values[0])
        weather = pd.concat([weather, temp_df], axis=0)

# %%
weather.head(1)
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE  AWND BackupDirection  \
# 0  72565003017  2015-07-01T00:53:00       FM-15       7   NaN             NaN
#
#    BackupDistance BackupDistanceUnit      BackupElements  BackupElevation  \
# 0             NaN                NaN  SNOWFALL, SNOWDPTH           5350.0
#
#    ...  ShortDurationPrecipitationValue060 ShortDurationPrecipitationValue080  \
# 0  ...                                 NaN                                NaN
#
#    ShortDurationPrecipitationValue100  ShortDurationPrecipitationValue120  \
# 0                                 NaN                                 NaN
#
#   ShortDurationPrecipitationValue150  ShortDurationPrecipitationValue180  \
# 0                                NaN                                 NaN
#
#    Sunrise  Sunset  TStorms WindEquipmentChangeDate
# 0      NaN     NaN      NaN              2005-09-12
#
# [1 rows x 124 columns]

# %%
# Many columns has very few useful rows. Collect only useful columns.
columns = weather.columns
num = len(weather)
num
# Out:
# 219964

# %%
useful_columns = []
for column in columns:
    if sum(weather[column].isna()) > 30000:
        # There are more than 10000 nan
        print('{} is abondoned, containing {} NaN'.format(column, sum(weather[column].isna())))
    else:
        useful_columns.append(column)
# Out:
# AWND is abondoned, containing 219764 NaN
# BackupDirection is abondoned, containing 112772 NaN
# BackupDistance is abondoned, containing 112772 NaN
# BackupDistanceUnit is abondoned, containing 112772 NaN
# BackupElements is abondoned, containing 54223 NaN
# BackupElevation is abondoned, containing 54223 NaN
# BackupElevationUnit is abondoned, containing 219964 NaN
# BackupEquipment is abondoned, containing 112772 NaN
# BackupLatitude is abondoned, containing 54223 NaN
# BackupLongitude is abondoned, containing 54223 NaN
# BackupName is abondoned, containing 54223 NaN
# CDSD is abondoned, containing 219764 NaN
# CLDD is abondoned, containing 219764 NaN
# DSNW is abondoned, containing 219792 NaN
# DailyAverageDewPointTemperature is abondoned, containing 213892 NaN
# DailyAverageDryBulbTemperature is abondoned, containing 213796 NaN
# DailyAverageRelativeHumidity is abondoned, containing 213883 NaN
# DailyAverageSeaLevelPressure is abondoned, containing 213901 NaN
# DailyAverageStationPressure is abondoned, containing 213806 NaN
# DailyAverageWetBulbTemperature is abondoned, containing 213892 NaN
# DailyAverageWindSpeed is abondoned, containing 213796 NaN
# DailyCoolingDegreeDays is abondoned, containing 213796 NaN
# DailyDepartureFromNormalAverageTemperature is abondoned, containing 213796 NaN
# DailyHeatingDegreeDays is abondoned, containing 213796 NaN
# DailyMaximumDryBulbTemperature is abondoned, containing 213796 NaN
# DailyMinimumDryBulbTemperature is abondoned, containing 213796 NaN
# DailyPeakWindDirection is abondoned, containing 213808 NaN
# DailyPeakWindSpeed is abondoned, containing 213808 NaN
# DailyPrecipitation is abondoned, containing 213796 NaN
# DailySnowDepth is abondoned, containing 214742 NaN
# DailySnowfall is abondoned, containing 214619 NaN
# DailySustainedWindDirection is abondoned, containing 213796 NaN
# DailySustainedWindSpeed is abondoned, containing 213796 NaN
# DailyWeather is abondoned, containing 216975 NaN
# HDSD is abondoned, containing 219764 NaN
# HTDD is abondoned, containing 219764 NaN
# HeavyFog is abondoned, containing 219964 NaN
# HourlyAltimeterSetting is abondoned, containing 42803 NaN
# HourlyPrecipitation is abondoned, containing 61024 NaN
# HourlyPresentWeatherType is abondoned, containing 182054 NaN
# HourlyPressureChange is abondoned, containing 135084 NaN
# HourlyPressureTendency is abondoned, containing 135084 NaN
# HourlySeaLevelPressure is abondoned, containing 35945 NaN
# HourlyWindGustSpeed is abondoned, containing 205326 NaN
# MonthlyAverageRH is abondoned, containing 219964 NaN
# MonthlyDaysWithGT001Precip is abondoned, containing 219764 NaN
# MonthlyDaysWithGT010Precip is abondoned, containing 219764 NaN
# MonthlyDaysWithGT32Temp is abondoned, containing 219764 NaN
# MonthlyDaysWithGT90Temp is abondoned, containing 219764 NaN
# MonthlyDaysWithLT0Temp is abondoned, containing 219764 NaN
# MonthlyDaysWithLT32Temp is abondoned, containing 219764 NaN
# MonthlyDepartureFromNormalAverageTemperature is abondoned, containing 219764 NaN
# MonthlyDepartureFromNormalCoolingDegreeDays is abondoned, containing 219764 NaN
# MonthlyDepartureFromNormalHeatingDegreeDays is abondoned, containing 219836 NaN
# MonthlyDepartureFromNormalMaximumTemperature is abondoned, containing 219836 NaN
# MonthlyDepartureFromNormalMinimumTemperature is abondoned, containing 219764 NaN
# MonthlyDepartureFromNormalPrecipitation is abondoned, containing 219779 NaN
# MonthlyDewpointTemperature is abondoned, containing 219964 NaN
# MonthlyGreatestPrecip is abondoned, containing 219764 NaN
# MonthlyGreatestPrecipDate is abondoned, containing 219764 NaN
# MonthlyGreatestSnowDepth is abondoned, containing 219795 NaN
# MonthlyGreatestSnowDepthDate is abondoned, containing 219908 NaN
# MonthlyGreatestSnowfall is abondoned, containing 219791 NaN
# MonthlyGreatestSnowfallDate is abondoned, containing 219880 NaN
# MonthlyMaxSeaLevelPressureValue is abondoned, containing 219764 NaN
# MonthlyMaxSeaLevelPressureValueDate is abondoned, containing 219764 NaN
# MonthlyMaxSeaLevelPressureValueTime is abondoned, containing 219764 NaN
# MonthlyMaximumTemperature is abondoned, containing 219764 NaN
# MonthlyMeanTemperature is abondoned, containing 219764 NaN
# MonthlyMinSeaLevelPressureValue is abondoned, containing 219764 NaN
# MonthlyMinSeaLevelPressureValueDate is abondoned, containing 219764 NaN
# MonthlyMinSeaLevelPressureValueTime is abondoned, containing 219764 NaN
# MonthlyMinimumTemperature is abondoned, containing 219764 NaN
# MonthlySeaLevelPressure is abondoned, containing 219770 NaN
# MonthlyStationPressure is abondoned, containing 219769 NaN
# MonthlyTotalLiquidPrecipitation is abondoned, containing 219779 NaN
# MonthlyTotalSnowfall is abondoned, containing 219880 NaN
# MonthlyWetBulb is abondoned, containing 219964 NaN
# NormalsCoolingDegreeDay is abondoned, containing 219764 NaN
# NormalsHeatingDegreeDay is abondoned, containing 219764 NaN
# ShortDurationEndDate005 is abondoned, containing 219793 NaN
# ShortDurationEndDate010 is abondoned, containing 219793 NaN
# ShortDurationEndDate015 is abondoned, containing 219793 NaN
# ShortDurationEndDate020 is abondoned, containing 219793 NaN
# ShortDurationEndDate030 is abondoned, containing 219793 NaN
# ShortDurationEndDate045 is abondoned, containing 219793 NaN
# ShortDurationEndDate060 is abondoned, containing 219793 NaN
# ShortDurationEndDate080 is abondoned, containing 219793 NaN
# ShortDurationEndDate100 is abondoned, containing 219793 NaN
# ShortDurationEndDate120 is abondoned, containing 219793 NaN
# ShortDurationEndDate150 is abondoned, containing 219793 NaN
# ShortDurationEndDate180 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue005 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue010 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue015 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue020 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue030 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue045 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue060 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue080 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue100 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue120 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue150 is abondoned, containing 219793 NaN
# ShortDurationPrecipitationValue180 is abondoned, containing 219793 NaN
# Sunrise is abondoned, containing 213796 NaN
# Sunset is abondoned, containing 213796 NaN
# TStorms is abondoned, containing 219964 NaN

# %%
weather = weather[useful_columns]

# %%
weather.head(1)
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE  \
# 0  72565003017  2015-07-01T00:53:00       FM-15       7
#
#   HourlyDewPointTemperature HourlyDryBulbTemperature HourlyRelativeHumidity  \
# 0                        54                       68                     61
#
#      HourlySkyConditions HourlyStationPressure HourlyVisibility  \
# 0  SCT:04 110 BKN:07 220                 24.65            10.00
#
#   HourlyWetBulbTemperature HourlyWindDirection  HourlyWindSpeed  \
# 0                       59                 250              7.0
#
#                                                  REM REPORT_TYPE.1  SOURCE.1  \
# 0  MET10507/01/15 00:53:02 METAR KDEN 010753Z 250...         FM-15         7
#
#   WindEquipmentChangeDate
# 0              2005-09-12

# %%
def round_time(date_time):
    minute = date_time.minute
    if minute > 30:
        return date_time+timedelta(hours=1)
    else:
        return date_time

# %%
def parse_temperature(s):
    try:
        return float(s)
    except:
        try:
            return float(re.split('[a-z]+', s)[0])
        except:
            return np.nan

# %%
# Round the date info
weather['datetime'] = pd.to_datetime(weather['DATE'], format='%Y-%m-%dT%H:%M:%S')
weather['date'] = weather['datetime'].apply(lambda date_time: round_time(date_time))
weather['time'] = weather['date'].apply(lambda x:x.hour)
weather['month'] = weather['date'].apply(lambda x:x.month)
weather['day'] = weather['date'].apply(lambda x:x.day)
# weather['weekday'] = weather['date'].apply(lambda x:x.weekday())
weather['year'] = weather['date'].apply(lambda x:x.year)
weather['HourlyDryBulbTemperature'] = weather['HourlyDryBulbTemperature'].apply(lambda s:parse_temperature(s))

# %%
# Get rid of nan and duplicated values
match_columns = ['year', 'month', 'day', 'time']
useful_columns = ['STATION', 'DATE', 'HourlyDryBulbTemperature', 'month', 'day', 'time', 'year']
weather = weather.loc[weather['HourlyDryBulbTemperature'].notna(),:]
weather = weather[useful_columns].groupby(match_columns+['STATION'], as_index=False).mean()
weather.head(3)
# Out:
#    year  month  day  time      STATION  HourlyDryBulbTemperature
# 0  2015      7    1     1  72565003017                      68.0
# 1  2015      7    1     1  72572024127                      80.0
# 2  2015      7    1     1  72698024229                      68.0

# %%
'''
houston = weather.loc[weather['STATION'] == 72243012960,:]
san_antonio = weather.loc[weather['STATION'] == 72259003927,:]
dallas = weather.loc[weather['STATION'] == 72253012921,:]
'''

# %% [markdown]
# # Merge the electricity data with the temprature data

# %%
'''
df_joined = electricity_demand.merge(houston, how='inner', left_on=match_columns, right_on=match_columns)
df_joined = df_joined.merge(san_antonio, how='inner', left_on=match_columns, right_on=match_columns)
df_joined = df_joined.merge(dallas, how='inner', left_on=match_columns, right_on=match_columns)
'''
# bad_station = [72232403071]
bad_station = []
df_joined = electricity_demand

for station in stations:
    if station not in bad_station:
        df_tmp = weather.loc[weather['STATION'] == station, :]
        if sum(df_tmp['HourlyDryBulbTemperature'].isna()) != 0:
            print(station)
        df_joined = df_joined.merge(df_tmp, how='inner', left_on=match_columns, right_on=match_columns)

# %%
'''
new_column_names = ['datetime', 'usage', 'time', 'month', 'weekday', 'year', 'day',
       'normalized_usage', 'STATION_1', 'T_1',
       'STATION_2', 'T_2', 'STATION_3', 'T_3', 'STATION_4', 'T_4',
       'STATION_5', 'T_5', 'STATION_6', 'T_6', 'STATION_7', 'T_7',
       'STATION_8', 'T_8', 'STATION_9', 'T_9', 'STATION_10', 'T_10',
       'STATION_11', 'T_11', 'STATION_12', 'T_12']
'''

new_column_names = ['datetime', 'usage', 'time', 'month', 'weekday', 'year', 'day',
       'normalized_usage', 'STATION_1', 'T_1',
       'STATION_2', 'T_2', 'STATION_3', 'T_3', 'STATION_4', 'T_4']

df_joined.columns = new_column_names
# df_joined = df_joined.drop(columns=['STATION_x', 'STATION_y', 'STATION']).rename(columns={'HourlyDryBulbTemperature_x':'T_Houston','HourlyDryBulbTemperature_y':'T_san_antonio','HourlyDryBulbTemperature':'T_dallas'})
# df_joined.to_csv('electricity_with_temperature.csv')
df_joined.head(3)
# Out:
#              datetime  usage  time  month  weekday  year  day  \
# 0 2019-09-18 22:06:00  40510    22      9        2  2019   18
# 1 2019-09-18 21:06:00  41726    21      9        2  2019   18
# 2 2019-09-18 20:06:00  41714    20      9        2  2019   18
#
#    normalized_usage    STATION_1   T_1    STATION_2   T_2    STATION_3   T_3  \
# 0          0.601575  72565003017  67.0  72572024127  73.0  72793024233  59.0
# 1          0.627950  72565003017  63.0  72572024127  73.0  72793024233  60.0
# 2          0.627690  72565003017  70.0  72572024127  71.0  72793024233  59.0
#
#      STATION_4   T_4
# 0  72698024229  57.0
# 1  72698024229  57.0
# 2  72698024229  59.0

# %%
# df_joined = pd.read_csv('electricity_with_temperature.csv',index_col=0)
df_joined = df_joined.sort_values(['datetime']).reset_index(drop=True)

# %%
pd.set_option('display.max_columns',100)
df_joined.head(3)
# Out:
#              datetime  usage  time  month  weekday  year  day  \
# 0 2015-07-01 01:06:00  12775     1      7        2  2015    1
# 1 2015-07-01 02:06:00  34914     2      7        2  2015    1
# 2 2015-07-01 03:06:00  33142     3      7        2  2015    1
#
#    normalized_usage    STATION_1   T_1    STATION_2   T_2    STATION_3   T_3  \
# 0          0.000000  72565003017  68.0  72572024127  80.0  72793024233  68.0
# 1          0.480197  72565003017  66.0  72572024127  79.0  72793024233  66.0
# 2          0.441762  72565003017  67.0  72572024127  79.0  72793024233  63.0
#
#      STATION_4   T_4
# 0  72698024229  68.0
# 1  72698024229  66.0
# 2  72698024229  65.0

# %% [markdown]
# ## Produce some sample data for the database

# %%
sample_for_app = df_joined.tail(336)
sample_for_app = sample_for_app[['datetime','usage','T_1','T_2','T_3']]
sample_for_app['temperatures'] = sample_for_app.apply(lambda row: ',,'.join([str(t) for t in row[['T_1','T_2','T_3']].values]), axis=1)

# %%
sample_for_app = sample_for_app[['datetime','usage','temperatures']]
sample_for_app['prediction'] = sample_for_app['usage']+1000
sample_for_app['net_gen'] = sample_for_app['usage']+1000
sample_for_app['region'] = 'TEX'

# %%
sample_for_app.head(3)
# sample_for_app.to_csv('sample', index=False)
# Out:
#                   datetime  usage      temperatures  prediction  net_gen  \
# 32760  2019-09-04 19:05:00  66328  88.0,,88.0,,92.0       67328    67328
# 32761  2019-09-04 20:05:00  63835  86.0,,85.0,,90.0       64835    64835
# 32762  2019-09-04 21:05:00  61881  83.0,,85.0,,88.0       62881    62881
#
#       region
# 32760    TEX
# 32761    TEX
# 32762    TEX

# %%
MONGODB_HOST = 'localhost'
MONGODB_PORT = 27017
DBS_NAME = 'donorschoose'
COLLECTION_NAME = 'electricity_prediction'

connection = MongoClient(MONGODB_HOST, MONGODB_PORT)
collection = connection[DBS_NAME][COLLECTION_NAME]

# %%
for ind, row in sample_for_app.iterrows():
    collection.insert_one({'datetime':datetime.strptime(row['datetime'], '%Y-%m-%d %H:%M:%S'),
                           'usage':row['usage'],
                           'temperatures':row['temperatures'],
                           'prediction':row['prediction'],
                           'net_gen':row['net_gen'],
                           'region':row['region']})

# %%
new_item = {'datetime':datetime.strptime('2019-09-06 00:00:00', '%Y-%m-%d %H:%M:%S'),
                           'usage':60000,
                           'temperatures':"82,,33,,46",
                           'prediction':60000,
                           'net_gen':6000,
                           'region':'CAL'}

# %%
new_new_new = {'datetime':datetime.strptime('2019-09-06 00:01:00', '%Y-%m-%d %H:%M:%S'),
                           'usage':70000,
                           'temperatures':"81,,33,,46",
                           'prediction':70000,
                           'net_gen':70000,
                           'region':'NW'}

# %%
collection.insert_one(new_new_new)

# %%
elec_regions = {'NW':{'WA','OR','NV','MT','ID','WY','UT','CO'},
               'CAL':{'CA'},
               'SW':{'AZ','NM'},
               'CENT':{'ND','SD','NE','KS','OK'},
               'CAR':{'NC','SC'},
               'FLA':{'FL'},
               'MIDA':{'OH','PA','WV','VA','MD','DE','NJ'},
               'MIDW':{'MN','IA','MO','AR','LA','WI','IL','MI','IN'},
               'NE':{'VT','NH','MA','CT','RI','ME'},
               'NY':{'NY'},
               'SE':{'MS','AL','GA'},
               'TEN':{'KY','TN'},
               'TEX':{'TX'}}

for k, v in elec_regions.items():
    if k not in ['TEX','CAL','NW']:
        new_item['datetime'] = new_item['datetime']+timedelta(minutes=10)
        new_item['usage'] = new_item['usage']+1000
        new_item['region'] = k
        collection.insert_one(new_item)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-12-78f8a8b9229f> in <module>
#      18         new_item['usage'] = new_item['usage']+1000
#      19         new_item['region'] = k
# ---> 20         collection.insert_one(new_item)
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     698                          write_concern=write_concern,
#     699                          bypass_doc_val=bypass_document_validation,
# --> 700                          session=session),
#     701             write_concern.acknowledged)
#     702
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     612             return self._insert_one(
#     613                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 614                 bypass_doc_val, session)
#     615
#     616         ids = []
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     600
#     601         self.__database.client._retryable_write(
# --> 602             acknowledged, _insert_command, session)
#     603
#     604         if not isinstance(doc, RawBSONDocument):
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1278         """Internal retryable write helper."""
#    1279         with self._tmp_session(session) as s:
# -> 1280             return self._retry_with_session(retryable, func, s, None)
#    1281
#    1282     def __reset_server(self, address):
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1231                             raise last_error
#    1232                         retryable = False
# -> 1233                     return func(session, sock_info, retryable)
#    1234             except ServerSelectionTimeoutError:
#    1235                 if is_retrying():
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/collection.py in _insert_command(session, sock_info, retryable_write)
#     597                 retryable_write=retryable_write)
#     598
# --> 599             _check_write_command_response(result)
#     600
#     601         self.__database.client._retryable_write(
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/helpers.py in _check_write_command_response(result)
#     215     write_errors = result.get("writeErrors")
#     216     if write_errors:
# --> 217         _raise_last_write_error(write_errors)
#     218
#     219     error = result.get("writeConcernError")
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/helpers.py in _raise_last_write_error(write_errors)
#     196     error = write_errors[-1]
#     197     if error.get("code") == 11000:
# --> 198         raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     199     raise WriteError(error.get("errmsg"), error.get("code"), error)
#     200
#
# DuplicateKeyError: E11000 duplicate key error collection: donorschoose.electricity_prediction index: _id_ dup key: { _id: ObjectId('5d9d4c9dc831c6e69e4fae6f') }

# %%
collection.insert_one(new_item)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-11-9bd3e93a353d> in <module>
# ----> 1 collection.insert_one(new_item)
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     698                          write_concern=write_concern,
#     699                          bypass_doc_val=bypass_document_validation,
# --> 700                          session=session),
#     701             write_concern.acknowledged)
#     702
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     612             return self._insert_one(
#     613                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 614                 bypass_doc_val, session)
#     615
#     616         ids = []
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     600
#     601         self.__database.client._retryable_write(
# --> 602             acknowledged, _insert_command, session)
#     603
#     604         if not isinstance(doc, RawBSONDocument):
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1278         """Internal retryable write helper."""
#    1279         with self._tmp_session(session) as s:
# -> 1280             return self._retry_with_session(retryable, func, s, None)
#    1281
#    1282     def __reset_server(self, address):
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1231                             raise last_error
#    1232                         retryable = False
# -> 1233                     return func(session, sock_info, retryable)
#    1234             except ServerSelectionTimeoutError:
#    1235                 if is_retrying():
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/collection.py in _insert_command(session, sock_info, retryable_write)
#     597                 retryable_write=retryable_write)
#     598
# --> 599             _check_write_command_response(result)
#     600
#     601         self.__database.client._retryable_write(
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/helpers.py in _check_write_command_response(result)
#     215     write_errors = result.get("writeErrors")
#     216     if write_errors:
# --> 217         _raise_last_write_error(write_errors)
#     218
#     219     error = result.get("writeConcernError")
#
# ~/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pymongo/helpers.py in _raise_last_write_error(write_errors)
#     196     error = write_errors[-1]
#     197     if error.get("code") == 11000:
# --> 198         raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     199     raise WriteError(error.get("errmsg"), error.get("code"), error)
#     200
#
# DuplicateKeyError: E11000 duplicate key error collection: donorschoose.electricity_prediction index: _id_ dup key: { _id: ObjectId('5d9d4c9dc831c6e69e4fae6f') }

# %%
df_sample = df_joined.sample(1000)

fig, ax = plt.subplots(figsize=(5,4))
sns.scatterplot(x='T_1', y='time', hue='normalized_usage', data=df_sample, ax=ax, legend=False)
ax.set_xlabel('Temperature of Houston($^\circ$F)')
ax.set_ylabel('24 Hours')
#sns.scatterplot(x='T_san_antonio', y='time', hue='normalized_usage', data=df_sample, ax=ax[1], legend=False)
#_ = sns.scatterplot(x='T_dallas', y='time', hue='normalized_usage', data=df_sample, ax=ax[2], legend=False)
# _ = sns.stripplot(x='weekday', y='time', hue='normalized_usage', data=df_sample, ax=ax[3])
# Out:
# Text(0, 0.5, '24 Hours')

# %%
df_hourly_agg = df_joined[['time', 'weekday', 'usage']].groupby(['time', 'weekday'], as_index=False).mean()
_ = sns.scatterplot(x='weekday', y='time', hue='usage', data=df_hourly_agg, legend=False)

# %%
print('Total number of hours: {}'.format(len(df_joined)))
df_joined = df_joined.sort_values('datetime')
# Out:
# Total number of hours: 36958

# %%
# Split the train, validation, test dataset.
total_rows = len(df_joined)
split_num = 28175
valid_index = []
test_index = []
# we want the test and validation set to both cover an entire year. Therefore, they are taking alternative weeks.
for h in np.arange(split_num,total_rows,336):
    valid_index.extend(list(np.arange(h,h+168)))
    test_index.extend(list(np.arange(h+168,h+336)))

# remove indexes larger than 36935
while valid_index[-1] >= total_rows:
    valid_index.pop()

while test_index[-1] >= total_rows:
    test_index.pop()
    
valid_index = np.asarray(valid_index)
test_index = np.asarray(test_index)

fitting_index=28175
train_index=23175
# np.savetxt('valid_index.txt', valid_index)
# np.savetxt('test_index.txt', test_index)

# %%
def attenuate(X,Y,beta,column):
    # The first 24 hour will be used as warm up.
    X_new = (1-beta)*X[24:, column:].copy()
    # X_new += 0.9*X[23:-1,column:]+0.9*X[22:-2,column:]+0.9*X[21:-3,column:]+0.9*X[20:-4,column:]# +0.9*X[19:-5,column:]+0.9*X[18:-6,column:]
    # for h in np.arange(1, 6):
        # X_new = np.concatenate((X_new, X[24-h:-1*h,column:]), axis=1)
    for h in np.arange(1, 24):
        X_new += beta**h*(1-beta)*X[24-h:-1*h, column:]
    return np.concatenate((X[24:,:column], X_new), axis=1), Y[24:]

# %%
# features = ['time', 'weekday', 'month'] + ['T_1','T_2','T_5','T_12']
features = ['time', 'weekday', 'month'] + ['T_1','T_2','T_3','T_4']
# features = ['time', 'weekday', 'month', 'T_Houston', 'T_san_antonio', 'T_dallas'] # month may can be abondoned
X = df_joined[features].values
Y = df_joined['usage'].values

def building_temp(beta):
    column = 3

    X_train = X[:train_index]# X[0:15706, :]
    Y_train = Y[:train_index]# Y[0:15706]
    # X_fitting = X[train_index:fitting_index]
    # Y_fitting = Y[train_index:fitting_index]
    X_train, Y_train = attenuate(X_train, Y_train, beta, column)
    # X_fitting, Y_fitting = attenuate(X_fitting, Y_fitting, beta, column)
    X_valid = X[valid_index]# X[15706:20941,:]
    Y_valid = Y[valid_index]# Y[15706:20941]
    # X_test = X[test_index]
    # Y_test = Y[test_index]
    X_valid, Y_valid = attenuate(X_valid, Y_valid, beta, column)
    # X_test, Y_test = attenuate(X_test, Y_test, beta, column)

    # X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=1)
    # X_valid, X_test, Y_valid, Y_test = train_test_split(X_test, Y_test, test_size=0.5, random_state=1)
    
    # For X_valid and X_test we also need to get rid of every monday.
    new_valid_index = []
    # new_test_index = []

    for h in np.arange(0, len(X_valid), 168):
        new_valid_index.extend(list(np.arange(h,h+144)))
        # new_test_index.extend(list(np.arange(h,h+144)))

    # remove indexes larger than 36935
    while new_valid_index[-1] >= len(X_valid):
        new_valid_index.pop()

    # while new_test_index[-1] >= len(X_test):
        # new_test_index.pop()

    new_valid_index = np.asarray(new_valid_index)
    # new_test_index = np.asarray(new_test_index)
    X_valid = X_valid[new_valid_index]
    Y_valid = Y_valid[new_valid_index]
    # X_test = X_test[new_test_index]
    # Y_test = Y_test[new_test_index]
    
    return X_train, Y_train, X_valid, Y_valid

# %%
'''
# One-hot encode 'time' and 'weekday'
def one_hot(raw):
    time = raw[:,1].reshape(-1).astype(int)
    raw = np.concatenate((raw[:,2:], raw[:,:1]), axis=1)
    nb_classes = 24
    time_one_hot = np.eye(nb_classes)[time]
    new = np.concatenate((time_one_hot, raw), axis=1)
    return new
'''
# Out:
# "\n# One-hot encode 'time' and 'weekday'\ndef one_hot(raw):\n    time = raw[:,1].reshape(-1).astype(int)\n    raw = np.concatenate((raw[:,2:], raw[:,:1]), axis=1)\n    nb_classes = 24\n    time_one_hot = np.eye(nb_classes)[time]\n    new = np.concatenate((time_one_hot, raw), axis=1)\n    return new\n"

# %%
'''
# Try increasing the weights of the points with high temperatures.
multiples = 100
X_over = []# oversampled X.
Y_over = []
for x,y in zip(X_train,Y_train):
    if x[2] > 90 or x[3] > 90 or x[4] > 90:
        for i in np.arange(multiples):
            X_over.append(list(x))
            Y_over.append(y)
    else:
        X_over.append(list(x))
        Y_over.append(y)
'''
# Out:
# '\n# Try increasing the weights of the points with high temperatures.\nmultiples = 100\nX_over = []# oversampled X.\nY_over = []\nfor x,y in zip(X_train,Y_train):\n    if x[2] > 90 or x[3] > 90 or x[4] > 90:\n        for i in np.arange(multiples):\n            X_over.append(list(x))\n            Y_over.append(y)\n    else:\n        X_over.append(list(x))\n        Y_over.append(y)\n'

# %%
from sklearn import base
from sklearn.metrics import make_scorer

class elec_forcast(base.BaseEstimator):
    
    def __init__(self, n_estimators=700, min_samples_split=4, min_samples_leaf=2, max_features=3, random_state=10):
        self.n_estimators = n_estimators
        self.min_samples_split = min_samples_split
        self.min_samples_leaf = min_samples_leaf
        self.max_features = max_features
        self.random_state = random_state
        self.rf = RF(n_estimators=self.n_estimators, min_samples_split=self.min_samples_split, \
                    min_samples_leaf=self.min_samples_leaf, max_features=self.max_features, \
                    random_state=self.random_state)
        
    def get_params(self, deep=True):
        return {"n_estimators": self.n_estimators,
                "min_samples_split":self.min_samples_split,
                "min_samples_leaf": self.min_samples_leaf,
                "max_features": self.max_features,
                "random_state": self.random_state}
        
    def fit(self, X, y):
        self.rf.fit(X,y)
        return self
        
    def predict(self, X, y):
        Y_pred = self.rf.predict(X)
        Y_pred = LR().fit(Y_pred.reshape(-1,1), y.reshape(-1,1)).predict(Y_pred.reshape(-1,1))        
        return Y_pred       
        
    def score(self, X, Y_true):
        Y_pred = self.predict(X, Y_true)
        return r2_score(Y_true, Y_pred)

# %%
# Perform grid search to look for the best parameters
grid = {'n_estimators': [200],
       'min_samples_split': [2,4],
       'min_samples_leaf': [1,2],
       'max_features': [0.3,0.5,0.7],
       'random_state': [10]}

max_r2 = -np.inf
best_params = None
best_beta = None
bar = tqdm_notebook(total=2*2*3)

for beta in [0.83,0.84,0.85]:
    X_train, Y_train, X_valid, Y_valid = building_temp(beta)
    train_end = len(X_train)
    valid_end = train_end+len(Y_valid)
    train_ind = np.arange(train_end)
    valid_ind = np.arange(train_end, valid_end)
    # Concatenate the train and validation set.
    X_total = np.concatenate((X_train, X_valid), axis=0)
    Y_total = np.concatenate((Y_train, Y_valid))
    search = GridSearchCV(elec_forcast(), grid, cv=[(train_ind, valid_ind)], n_jobs=4, verbose=10)
    search.fit(X_total, Y_total)
    # The best parameters.
    r2 = search.best_score_
    p = search.best_params_
    if max_r2 < r2:
        max_r2 = r2
        best_params = p
        best_beta = beta
    print('Best R2 score {} for {}.'.format(r2, beta))
    
    bar.update(3*2**4)
bar.close()
        
print('The maximum R2 score is: {} \n The best parameters are: {} \n The best beta is: {}'.format(max_r2, best_params, best_beta))
# Out:
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=4)]: Done   7 out of  12 | elapsed:  1.8min remaining:  1.3min
# [Parallel(n_jobs=4)]: Done   9 out of  12 | elapsed:  2.6min remaining:   51.4s
# [Parallel(n_jobs=4)]: Done  12 out of  12 | elapsed:  2.6min finished
# Best R2 score 0.9783951673363801 for 0.83.
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=4)]: Done   7 out of  12 | elapsed:  1.9min remaining:  1.4min
# [Parallel(n_jobs=4)]: Done   9 out of  12 | elapsed:  2.8min remaining:   55.5s
# [Parallel(n_jobs=4)]: Done  12 out of  12 | elapsed:  2.8min finished
# Best R2 score 0.9785612682505589 for 0.84.
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=4)]: Done   7 out of  12 | elapsed:  1.9min remaining:  1.3min
# [Parallel(n_jobs=4)]: Done   9 out of  12 | elapsed:  2.8min remaining:   56.6s
# [Parallel(n_jobs=4)]: Done  12 out of  12 | elapsed:  2.8min finished
# Best R2 score 0.978633654491114 for 0.85.
#
# The maximum R2 score is: 0.978633654491114
#  The best parameters are: {'min_samples_leaf': 1, 'n_estimators': 200, 'min_samples_split': 2, 'max_features': 0.3, 'random_state': 10}
#  The best beta is: 0.85

# %%
print(best_params,best_beta)
# Out:
# {'min_samples_leaf': 1, 'n_estimators': 200, 'min_samples_split': 2, 'max_features': 0.3, 'random_state': 10} 0.85

# %% [markdown]
# Current best parameters: {'random_state': 1, 'max_features': 1, 'min_samples_split': 2, 'n_estimators': 700, 'min_samples_leaf': 1, 'beta': 0.85} 0.9771
# {'random_state': 1, 'max_features': 1, 'min_samples_split': 2, 'n_estimators': 600, 'min_samples_leaf': 1, 'beta': 0.83} 0.9773
# {'random_state': 1, 'max_features': 1, 'min_samples_split': 2, 'n_estimators': 550, 'min_samples_leaf': 1, 'beta':0.84} 0.9774
# {'random_state': 1, 'max_features': 1, 'min_samples_split': 2, 'n_estimators': 450, 'min_samples_leaf': 1, 'beta': 0.84} 0.9774

# %% [raw]
# # Stale Code
# # Perform grid search to look for the best parameters
# grid = {'n_estimators': [700,1000,1500],
#        'min_samples_split': [2,5,7],
#        'min_samples_leaf': [1,3,5],
#        'max_features': [1,3,5],
#        'random_state': [1,10,50]}
#
# def params(grid):
#     for n in grid['n_estimators']:
#         for ss in grid['min_samples_split']:
#             for sl in grid['min_samples_leaf']:
#                 for mf in grid['max_features']:
#                     for rs in grid['random_state']:
#                         yield {'n_estimators':n, 'min_samples_split':ss, \
#                                'min_samples_leaf':sl, 'max_features':mf, \
#                                 'random_state':rs}
#
# max_r2 = -np.inf
# best_params = None
# best_beta = None
# bar = tqdm_notebook(total=3*3*3*3*3*4)
# for p in params(grid):
#     for beta in [0.85,0.9,0.95]:
#         X_train, Y_train, X_valid, Y_valid = building_temp(beta)
#         RF_model = RF(**p).fit(X_train, Y_train)
#         Y_predict = RF_model.predict(X_valid)
#         Y_predict = LR().fit(Y_predict.reshape(-1,1), Y_valid.reshape(-1,1).reshape(-1,1)).predict(Y_predict.reshape(-1,1))
#         r2 = r2_score(Y_valid, Y_predict)
#         if max_r2 < r2:
#             max_r2 = r2
#             best_params = p
#             best_beta = beta
#         bar.update(1)
# bar.close()
#
# print('The maximum R2 score is: {} \n The best parameters are: {} \n The best beta is: {}'.format(max_r2, best_params, best_beta))

# %%
print(best_params,best_beta)
# Out:
# {'max_features': 3,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 700,
#  'random_state': 1}

# %%
X_train, Y_train, X_valid, Y_valid = building_temp(0.85)

# %%
best_params = {'n_estimators': 500, 'random_state': 1, 'min_samples_leaf': 1, 'max_features': 0.3, 'min_samples_split': 2}
RF_model = RF(**best_params).fit(X_train, Y_train)
# my_estimator = elec_forcast(**best_params).fit(X_train, Y_train)

# %%
Y_fitting_pred = RF_model.predict(X_fitting)
LR_model = LR().fit(Y_fitting_pred.reshape(-1,1), Y_fitting.reshape(-1,1))
print('coefficient and intercept of linear model {}, {}'.format(LR_model.coef_, LR_model.intercept_))
# Out:
# coefficient and intercept of linear model [[1.03397432]], [453.06358171]

# %%
# X_valid = one_hot(X_valid)
Y_predict = RF_model.predict(X_valid)
print('The R2 score is: {}'.format(r2_score(Y_valid, Y_predict*1.03305987-547)))
# Out:
# The R2 score is: 0.9188665079056765

# %%
X_visualize = X_valid[1600:2000]
Y_visualize = Y_valid[1600:2000]
plt.figure(figsize=(15,7))
Y_predict = RF_model.predict(X_visualize)
# Y_predict = my_estimator.predict(X_visualize, Y_visualize)

plt.plot(Y_predict, linewidth=4)
plt.plot(Y_visualize, linewidth=4)
# plt.plot(X_visualize[:,3]*100)
plt.xlabel('Time(hours)')
plt.ylabel('Electricity Usage(Megawatthours)')
plt.legend(['Prediction','True usage'])
plt.ylim([0,60000])
plt.show()

# %%
# Calculate the linear transform directly
Y_pred = RF_model.predict(X_valid)
LR_model = LR().fit(Y_pred.reshape(-1,1), Y_valid.reshape(-1,1))
print('coefficient and intercept of linear model {}, {}'.format(LR_model.coef_, LR_model.intercept_))
# Out:
# coefficient and intercept of linear model [[1.03305987]], [-547.2268215]

# %%
plt.figure(figsize=(12,6))
_ = plt.plot(Y_predict, Y_valid)

# %%
# Try assign more weights to high temperature
# Histogram of temperature
_ = sns.distplot(X[:,3], bins=100) # Interesting, what are these suddenly diappeared temperature?

# %%
# The temperature for the outliers.
X[16406:16431, 3]
# Out:
# array([68., 69., 74., 76., 77., 80., 82., 81., 91., 93., 94., 93., 90.,
#        86., 82., 79., 73., 68., 65., 65., 65., 65., 66., 67., 67.])

# %%
# The next day should be cold.
X[16431:16456, 3] # So the next day is indeed cold but there seems a sudden boost of the temperature in the first day.
# Out:
# array([66. , 67. , 68. , 67. , 67. , 69. , 72. , 76. , 81. , 80. , 76. ,
#        72. , 68. , 64. , 62. , 57. , 54.5, 53. , 53. , 53. , 53. , 53. ,
#        54. , 54. , 54. ])

# %%
# The previous day.
X[16385:16406, 3]
# Out:
# array([62.        , 63.        , 62.        , 64.        , 67.        ,
#        70.        , 72.        , 72.        , 68.        , 63.        ,
#        61.33333333, 59.        , 57.        , 56.25      , 55.        ,
#        54.        , 56.66666667, 58.        , 60.        , 62.        ,
#        64.5       ])

# %% [markdown]
# It doesn't seem like a problem of under-fitting.

# %% [markdown]
# Check I didn't make a mistake on the time and temperature

# %%
df_joined.loc[16406:16431,:]
# Out:
#                  datetime  usage  time  month  weekday  year  day  \
# 16406 2017-11-03 01:05:00  35535     1     11        4  2017    3
# 16407 2017-11-03 00:05:00  38185     0     11        4  2017    3
# 16408 2017-11-02 23:05:00  41482    23     11        3  2017    2
# 16409 2017-11-02 22:05:00  44388    22     11        3  2017    2
# 16410 2017-11-02 21:05:00  46465    21     11        3  2017    2
# 16411 2017-11-02 20:05:00  47663    20     11        3  2017    2
# 16412 2017-11-02 19:05:00  47727    19     11        3  2017    2
# 16413 2017-11-02 18:05:00  48875    18     11        3  2017    2
# 16414 2017-11-02 17:05:00  49346    17     11        3  2017    2
# 16415 2017-11-02 16:05:00  48482    16     11        3  2017    2
# 16416 2017-11-02 15:05:00  47294    15     11        3  2017    2
# 16417 2017-11-02 14:05:00  45762    14     11        3  2017    2
# 16418 2017-11-02 13:05:00  43908    13     11        3  2017    2
# 16419 2017-11-02 12:05:00  42318    12     11        3  2017    2
# 16420 2017-11-02 11:05:00  40897    11     11        3  2017    2
# 16421 2017-11-02 10:05:00  39206    10     11        3  2017    2
# 16422 2017-11-02 09:05:00  37998     9     11        3  2017    2
# 16423 2017-11-02 08:05:00  37971     8     11        3  2017    2
# 16424 2017-11-02 07:05:00  36136     7     11        3  2017    2
# 16425 2017-11-02 06:05:00  32613     6     11        3  2017    2
# 16426 2017-11-02 05:05:00  30779     5     11        3  2017    2
# 16427 2017-11-02 04:05:00  30371     4     11        3  2017    2
# 16428 2017-11-02 03:05:00  30723     3     11        3  2017    2
# 16429 2017-11-02 02:05:00  31495     2     11        3  2017    2
# 16430 2017-11-02 01:05:00  32764     1     11        3  2017    2
# 16431 2017-11-02 00:05:00  34789     0     11        3  2017    2
#
#        normalized_usage  T_Houston  T_san_antonio   T_dallas
# 16406          0.204106  75.500000           68.0  74.000000
# 16407          0.258189  76.000000           69.0  74.000000
# 16408          0.325476  76.000000           74.0  73.000000
# 16409          0.384783  77.000000           76.0  72.000000
# 16410          0.427172  78.000000           77.0  77.000000
# 16411          0.451621  78.000000           80.0  75.000000
# 16412          0.452928  80.000000           82.0  76.000000
# 16413          0.476357  82.000000           81.0  79.000000
# 16414          0.485969  84.000000           91.0  84.000000
# 16415          0.468336  87.000000           93.0  85.000000
# 16416          0.444091  87.000000           94.0  83.000000
# 16417          0.412825  86.000000           93.0  82.000000
# 16418          0.374987  88.000000           90.0  79.000000
# 16419          0.342538  87.000000           86.0  76.333333
# 16420          0.313537  85.000000           82.0  76.000000
# 16421          0.279026  81.000000           79.0  73.000000
# 16422          0.254373  79.000000           73.0  72.250000
# 16423          0.253822  76.000000           68.0  72.000000
# 16424          0.216372  73.500000           65.0  71.500000
# 16425          0.144472  73.000000           65.0  71.000000
# 16426          0.107043  73.000000           65.0  70.000000
# 16427          0.098716  74.000000           65.0  69.500000
# 16428          0.105900  75.000000           66.0  69.000000
# 16429          0.121656  74.000000           67.0  69.000000
# 16430          0.147554  74.666667           67.0  70.000000
# 16431          0.188881  75.000000           66.0  69.000000

# %%
X[16415]
# Out:
# array([16.,  3., 87., 93., 85.])

# %%
Y[16415]
# Out:
# 48482

# %% [markdown]
# Not really

# %%
# That Saturday.
df_joined.loc[16406-48:16431-48,:]
# Out:
#                  datetime  usage  time  month  weekday  year  day  \
# 16358 2017-11-05 01:05:00  35487     1     11        6  2017    5
# 16359 2017-11-05 00:05:00  37675     0     11        6  2017    5
# 16360 2017-11-04 23:05:00  39986    23     11        5  2017    4
# 16361 2017-11-04 22:05:00  42045    22     11        5  2017    4
# 16362 2017-11-04 21:05:00  43676    21     11        5  2017    4
# 16363 2017-11-04 20:05:00  45121    20     11        5  2017    4
# 16364 2017-11-04 19:05:00  45604    19     11        5  2017    4
# 16365 2017-11-04 18:05:00  46811    18     11        5  2017    4
# 16366 2017-11-04 17:05:00  47343    17     11        5  2017    4
# 16367 2017-11-04 16:05:00  46857    16     11        5  2017    4
# 16368 2017-11-04 15:05:00  45657    15     11        5  2017    4
# 16369 2017-11-04 14:05:00  44169    14     11        5  2017    4
# 16370 2017-11-04 13:05:00  42773    13     11        5  2017    4
# 16371 2017-11-04 12:05:00  41170    12     11        5  2017    4
# 16372 2017-11-04 11:05:00  39392    11     11        5  2017    4
# 16373 2017-11-04 10:05:00  37292    10     11        5  2017    4
# 16374 2017-11-04 09:05:00  35244     9     11        5  2017    4
# 16375 2017-11-04 08:05:00  34040     8     11        5  2017    4
# 16376 2017-11-04 07:05:00  32685     7     11        5  2017    4
# 16377 2017-11-04 06:05:00  31481     6     11        5  2017    4
# 16378 2017-11-04 05:05:00  31046     5     11        5  2017    4
# 16379 2017-11-04 04:05:00  31241     4     11        5  2017    4
# 16380 2017-11-04 03:05:00  31752     3     11        5  2017    4
# 16381 2017-11-04 02:05:00  32747     2     11        5  2017    4
# 16382 2017-11-04 01:05:00  34274     1     11        5  2017    4
# 16383 2017-11-04 00:05:00  36398     0     11        5  2017    4
#
#        normalized_usage  T_Houston  T_san_antonio   T_dallas
# 16358          0.203127  74.000000          76.00  70.000000
# 16359          0.247781  74.000000          76.00  71.000000
# 16360          0.294945  74.000000          77.00  71.000000
# 16361          0.336966  75.000000          77.00  74.000000
# 16362          0.370252  76.000000          78.00  72.000000
# 16363          0.399743  77.000000          79.00  75.000000
# 16364          0.409600  79.000000          81.00  79.000000
# 16365          0.434233  81.000000          82.00  80.000000
# 16366          0.445091  83.000000          85.00  83.000000
# 16367          0.435172  85.000000          89.00  84.000000
# 16368          0.410682  85.000000          89.00  83.000000
# 16369          0.380314  86.000000          88.00  81.000000
# 16370          0.351824  84.000000          86.00  81.000000
# 16371          0.319109  84.000000          83.00  79.000000
# 16372          0.282822  81.500000          81.00  76.500000
# 16373          0.239964  79.000000          79.00  75.000000
# 16374          0.198167  75.666667          76.00  74.000000
# 16375          0.173595  73.333333          71.00  73.000000
# 16376          0.145942  71.500000          68.00  73.000000
# 16377          0.121370  69.600000          67.00  73.000000
# 16378          0.112492  69.000000          66.00  74.000000
# 16379          0.116472  68.500000          63.00  74.000000
# 16380          0.126901  73.000000          61.25  74.000000
# 16381          0.147207  73.000000          59.50  74.000000
# 16382          0.178371  74.000000          60.00  74.000000
# 16383          0.221719  74.000000          61.00  73.666667

# %%
# Try analyze the data with Houston in [87,89] San Antonio in [93,95] Dallas in [83,85]

X_in_range = X[(X[:,2] > 85) & (X[:,2] < 90) & (X[:,3] > 90) & (X[:,3] < 95) & (X[:,4] > 80) & (X[:,4] < 85)]
Y_in_range = Y[(X[:,2] > 85) & (X[:,2] < 90) & (X[:,3] > 90) & (X[:,3] < 95) & (X[:,4] > 80) & (X[:,4] < 85)]

# %%
_ = sns.scatterplot(x=X_in_range[:,1], y=X_in_range[:,0], hue=Y_in_range)

# %%
Y_in_range[X_in_range[:,1] == 2]
# Out:
# array([63832, 61092, 60316, 51361, 63226, 55173])

# %%
X_in_range = X_train[(X_train[:,2] > 85) & (X_train[:,2] < 90) & (X_train[:,3] > 90) & (X_train[:,3] < 95) & (X_train[:,4] > 80) & (X_train[:,4] < 85)]
Y_in_range = Y_train[(X_train[:,2] > 85) & (X_train[:,2] < 90) & (X_train[:,3] > 90) & (X_train[:,3] < 95) & (X_train[:,4] > 80) & (X_train[:,4] < 85)]

# %%
_ = sns.scatterplot(x=X_in_range[:,1], y=X_in_range[:,0], hue=Y_in_range)

# %%
ax = sns.lineplot(x=X[:,3], y=Y)
ax.set_xlabel('Temperature of Houston($^\circ$F)')
ax.set_ylabel('Electricity Demand(Megawatthours)')
# Out:
# Text(0, 0.5, 'Electricity Demand(Megawatthours)')

# %% [markdown]
# # Analyze the Present Data

# %%
# Load the electricity data from Sep 17 to Sep 24
elec_present = pd.read_csv('electricity_data/texas_sep_18.csv')

# %%
elec_present.head(1)
# Out:
#   Region Code Timestamp (Hour Ending)  Demand (MWh)  Demand Forecast (MWh)  \
# 0         TEX     9/17/2019 12 AM CDT         47072                48365.0
#
#    Net Generation (MWh)  Total Interchange (MWh)
# 0               46815.0                   -258.0

# %%
elec_present.columns
# Out:
# Index(['Region Code', 'Timestamp (Hour Ending)', 'Demand (MWh)',
#        'Demand Forecast (MWh)', 'Net Generation (MWh)',
#        'Total Interchange (MWh)'],
#       dtype='object')

# %%
elec_present = elec_present.loc[:,['Timestamp (Hour Ending)', 'Demand (MWh)', 'Demand Forecast (MWh)']]

# %%
elec_present = elec_present.rename(columns={'Timestamp (Hour Ending)':'datetime','Demand (MWh)':'usage','Demand Forecast (MWh)':'prediction'})

# %%
elec_present['datetime'] = pd.to_datetime(elec_present['datetime'], format='%m/%d/%Y %I %p CDT')
elec_present['time'] = elec_present['datetime'].apply(lambda x:x.hour)
elec_present['month'] = elec_present['datetime'].apply(lambda x:x.month)
elec_present['weekday'] = elec_present['datetime'].apply(lambda x:x.weekday())
elec_present['year'] = elec_present['datetime'].apply(lambda x:x.year)
elec_present['day'] = elec_present['datetime'].apply(lambda x:x.day)

# %%
# Load the weather data
weather_sep_18 = pd.read_csv('electricity_data/weather_sep_18.csv')
# Round the date info
weather_sep_18['datetime'] = pd.to_datetime(weather_sep_18['DATE'], format='%Y-%m-%dT%H:%M:%S')
weather_sep_18['date'] = weather_sep_18['datetime'].apply(lambda date_time: round_time(date_time))
weather_sep_18['time'] = weather_sep_18['date'].apply(lambda x:x.hour)
weather_sep_18['month'] = weather_sep_18['date'].apply(lambda x:x.month)
weather_sep_18['day'] = weather_sep_18['date'].apply(lambda x:x.day)
# weather_sep_18['weekday'] = weather_sep_18['date'].apply(lambda x:x.weekday())
weather_sep_18['year'] = weather_sep_18['date'].apply(lambda x:x.year)
weather_sep_18['HourlyDryBulbTemperature'] = weather_sep_18['HourlyDryBulbTemperature'].apply(lambda s:parse_temperature(s))
weather_sep_18 = weather_sep_18.loc[weather_sep_18['HourlyDryBulbTemperature'].notna(),:]
weather_sep_18 = weather_sep_18[useful_columns]
weather_sep_18 = weather_sep_18[useful_columns].groupby(match_columns+['STATION'], as_index=False).mean()
houston = weather_sep_18.loc[weather_sep_18['STATION'] == 72243012960,:]
san_antonio = weather_sep_18.loc[weather_sep_18['STATION'] == 72259003927,:]
dallas = weather_sep_18.loc[weather_sep_18['STATION'] == 72253012921,:]
df_sep_18 = elec_present.merge(houston, how='inner', left_on=match_columns, right_on=match_columns)
df_sep_18 = df_sep_18.merge(san_antonio, how='inner', left_on=match_columns, right_on=match_columns)
df_sep_18 = df_sep_18.merge(dallas, how='inner', left_on=match_columns, right_on=match_columns)
df_sep_18 = df_sep_18.drop(columns=['STATION_x', 'STATION_y', 'STATION']).rename(columns={'HourlyDryBulbTemperature_x':'T_Houston','HourlyDryBulbTemperature_y':'T_san_antonio','HourlyDryBulbTemperature':'T_dallas'})
df_sep_18 = df_sep_18.sort_values('datetime')

# %%
df_sep_18.head(1)
# Out:
#     datetime  usage  prediction  time  month  weekday  year  day  T_Houston  \
# 0 2019-09-17  47072     48365.0     0      9        1  2019   17       75.0
#
#    T_san_antonio  T_dallas
# 0           81.0      78.0

# %%
X_present = df_sep_18[features].values
Y_present = df_sep_18['usage'].values
X_present, Y_present = attenuate(X_present, Y_present, beta, 3)
Y_web_pred = df_sep_18['prediction'].values[25:]

# %%
from matplotlib.ticker import MultipleLocator

Y_pred = RF_model.predict(X_present)
fig,ax = plt.subplots(figsize=(15,7))
plt.plot(Y_present, 'b', linewidth=4)
plt.plot(Y_web_pred, 'y', linewidth=4)
plt.plot(Y_pred*1.09133847-1131, 'black', linewidth=4)
plt.xlabel('Date')
plt.ylabel('Electricity Usage(Megawatthours)')
plt.legend(['True usage', 'Prediction by EIA', 'My Random Forest'])
ax.xaxis.set_major_locator(MultipleLocator(24))
ax.set_xticklabels(['', 'Sep.18', 'Sep.19', 'Sep.20', 'Sep.21', 'Sep.22', 'Sep.23'])
plt.show()

# %% [markdown]
# ## Time Series Model

# %%
electricity_demand_sorted = electricity_demand.sort_values(['datetime']).reset_index(drop=True)

# %%
electricity_demand_sorted.head(3)
# Out:
#              datetime  usage  time  month  weekday  year  day
# 0 2015-07-01 01:05:00  37456     1      7        2  2015    1
# 1 2015-07-01 02:05:00  35119     2      7        2  2015    1
# 2 2015-07-01 03:05:00  33638     3      7        2  2015    1

# %%
# Make sure there is no missed hours.
wrong_intervals = []

for ind in np.arange(len(electricity_demand_sorted)-1):
    if electricity_demand_sorted.iloc[ind]['datetime']+timedelta(hours=1) != electricity_demand_sorted.iloc[ind+1]['datetime']:
        wrong_intervals.append(ind)

# %%
mean_removed = electricity_demand_sorted['usage'].values - np.mean(electricity_demand_sorted['usage'].values)
fft = np.fft.fft(mean_removed)
plt.plot(fft)
_ = plt.xlim([-100,5000])

# %%
# Peak for the daily cycle
daily_peak = np.where((fft < -3e7) | (fft > 1e7))[0]
print('the preak corresponding to the daily cycle: {}'.format(daily_peak))
# Out:
# the preak corresponding to the daily cycle: [    1     2     3     4     7     8     9   220  1539 35396 36715 36926
#  36927 36928 36931 36932 36933 36934]

# %% [markdown]
# 3 corresponding to something around 1.4 year
# 4 corresponding to something around 1.05 year
# 8 corresponding to something around 0.53 year ->
# 9 corresponding to something around 0.46 year -> These two should be corresponding to the half a year period (check whether there are pseudo periods)
# 220 corresponding to the weekly period (not that strong compared to the daily peak)
# 1539 corresponding to the daily period

# %% [markdown]
# ## Check to see how many harmonics we should include

# %%
plt.plot(fft)
_ = plt.xlim([0,600])

# %% [markdown]
# Let's fit a periodic model first.<br>
# three harmonics for the yearly cycle and two harmonics for the weekly and daily cycle.<br>
# Try the first three years as the training set first

# %%
df_for_periodic_model = electricity_demand_sorted.copy()

# %%
def diff_in_hours(x):
    # This function returns the number of hours from 2015-07-01 01:05:00
    minutes = (x-datetime(2015, 7, 1, 1, 5, 0)).total_seconds()/60
    if minutes % 60 > 30:
        return minutes/60 + 1
    else:
        return minutes/60
    
df_for_periodic_model['hours'] = electricity_demand_sorted['datetime'].apply(lambda x: diff_in_hours(x))

# %%
df_for_periodic_model.head(3)
# Out:
#              datetime  usage  time  month  weekday  year  day  hours  \
# 0 2015-07-01 01:05:00  37456     1      7        2  2015    1    0.0
# 1 2015-07-01 02:05:00  35119     2      7        2  2015    1    1.0
# 2 2015-07-01 03:05:00  33638     3      7        2  2015    1    2.0
#
#    yearly_sin  yearly_cos  ...  yearly_3_sin  yearly_3_cos  weekly_sin  \
# 0    0.000000    1.000000  ...      0.000000      1.000000    0.000000
# 1    0.000717    1.000000  ...      0.002150      0.999998    0.037391
# 2    0.001434    0.999999  ...      0.004301      0.999991    0.074730
#
#    weekly_cos  weekly_2_sin  weekly_2_cos  dayly_sin  dayly_cos  dayly_2_sin  \
# 0    1.000000      0.000000      1.000000   0.000000   1.000000     0.000000
# 1    0.999301      0.074730      0.997204   0.258819   0.965926     0.500000
# 2    0.997204      0.149042      0.988831   0.500000   0.866025     0.866025
#
#    dayly_2_cos
# 0     1.000000
# 1     0.866025
# 2     0.500000
#
# [3 rows x 22 columns]

# %%
# Construct the sin and cos columns.
def trig(func, period, x):
    # This function returns a sin or x value of x.
    return func(2*np.pi*x/period)

# Yearly period.
df_for_periodic_model['yearly_sin'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.sin, 365.25*24, x))
df_for_periodic_model['yearly_cos'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.cos, 365.25*24, x))
df_for_periodic_model['yearly_2_sin'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.sin, 365.25*24/2, x)) # Starting from here are harmonics
df_for_periodic_model['yearly_2_cos'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.cos, 365.25*24/2, x))
df_for_periodic_model['yearly_3_sin'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.sin, 365.25*24/3, x))
df_for_periodic_model['yearly_3_cos'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.cos, 365.25*24/3, x))
# Weekly period.
df_for_periodic_model['weekly_sin'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.sin, 7*24, x))
df_for_periodic_model['weekly_cos'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.cos, 7*24, x))
df_for_periodic_model['weekly_2_sin'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.sin, 7*24/2, x))
df_for_periodic_model['weekly_2_cos'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.cos, 7*24/2, x))
# Dayly period.
df_for_periodic_model['dayly_sin'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.sin, 24, x))
df_for_periodic_model['dayly_cos'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.cos, 24, x))
df_for_periodic_model['dayly_2_sin'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.sin, 24/2, x))
df_for_periodic_model['dayly_2_cos'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.cos, 24/2, x))
df_for_periodic_model['dayly_3_sin'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.sin, 24/3, x))
df_for_periodic_model['dayly_3_cos'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.cos, 24/3, x))
df_for_periodic_model['dayly_4_sin'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.sin, 24/4, x))
df_for_periodic_model['dayly_4_cos'] = df_for_periodic_model['hours'].apply(lambda x: trig(np.cos, 24/4, x))

# %%
df_for_periodic_model.head(3)
# Out:
#              datetime  usage  time  month  weekday  year  day  hours  \
# 0 2015-07-01 01:05:00  37456     1      7        2  2015    1    0.0
# 1 2015-07-01 02:05:00  35119     2      7        2  2015    1    1.0
# 2 2015-07-01 03:05:00  33638     3      7        2  2015    1    2.0
#
#    yearly_sin  yearly_cos  ...  yearly_3_sin  yearly_3_cos  weekly_sin  \
# 0    0.000000    1.000000  ...      0.000000      1.000000    0.000000
# 1    0.000717    1.000000  ...      0.002150      0.999998    0.037391
# 2    0.001434    0.999999  ...      0.004301      0.999991    0.074730
#
#    weekly_cos  weekly_2_sin  weekly_2_cos  dayly_sin  dayly_cos  dayly_2_sin  \
# 0    1.000000      0.000000      1.000000   0.000000   1.000000     0.000000
# 1    0.999301      0.074730      0.997204   0.258819   0.965926     0.500000
# 2    0.997204      0.149042      0.988831   0.500000   0.866025     0.866025
#
#    dayly_2_cos
# 0     1.000000
# 1     0.866025
# 2     0.500000
#
# [3 rows x 22 columns]

# %% [markdown]
# There is a slowly varying trend which should be handled first using a ridge regression.

# %%
df_for_periodic_model.tail(1)
# Out:
#                  datetime  usage  time  month  weekday  year  day    hours  \
# 36934 2019-09-18 23:05:00  51199    23      9        2  2019   18  36982.0
#
#        yearly_sin  yearly_cos  ...  yearly_3_sin  yearly_3_cos  weekly_sin  \
# 36934    0.980846    0.194783  ...     -0.831992     -0.554788    0.733052
#
#        weekly_cos  weekly_2_sin  weekly_2_cos  dayly_sin  dayly_cos  \
# 36934    0.680173      0.997204      -0.07473       -0.5   0.866025
#
#        dayly_2_sin  dayly_2_cos
# 36934    -0.866025          0.5
#
# [1 rows x 22 columns]

# %%
# Produce the x^2 and X^3 term for the ridge regressor

df_for_periodic_model['scaled_hours'] = df_for_periodic_model['hours']/100
df_for_periodic_model['scaled_hours_squared'] = df_for_periodic_model['scaled_hours']**2
df_for_periodic_model['scaled_hours_cubic'] = df_for_periodic_model['scaled_hours']**3

# %%
columns_x = ['scaled_hours', 'scaled_hours_squared', 'scaled_hours_cubic']
X = df_for_periodic_model[columns_x].values
y = df_for_periodic_model['usage'].values/1e4

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression

# search = GridSearchCV(Line, params, cv=5, n_jobs=4, verbose=10)
# _ = search.fit(X,y)
linear_trend = LinearRegression().fit(X[:,0].reshape(-1,1), y)

# %%
print(linear_trend.coef_, linear_trend.intercept_)
# Out:
# [0.00162474] 3.8928100300940485

# %%
plt.plot(X[:,0],y)
X_sample = np.arange(int(X[-1,0]))
_ = plt.plot(X_sample, linear_trend.predict(X_sample.reshape(-1,1)))

# %%
linear_trend.c
# Out:
# array([0.00162474])

# %%
def remove_trend(row):
    return row['usage']-(row['scaled_hours']*linear_trend.coef_[0]+linear_trend.intercept_)*1e4

df_for_periodic_model['usage_trend_removed'] = df_for_periodic_model[['usage','scaled_hours']].apply(lambda row: remove_trend(row), axis=1)

# Split the train, test and validation set

df_train = df_for_periodic_model.iloc[:train_index]
df_valid = df_for_periodic_model.iloc[valid_index]
df_test = df_for_periodic_model.iloc[test_index]

# %%
df_train.head(1)
# Out:
#              datetime  usage  time  month  weekday  year  day  hours  \
# 0 2015-07-01 01:05:00  37456     1      7        2  2015    1    0.0
#
#    yearly_sin  yearly_cos  ...  weekly_2_sin  weekly_2_cos  dayly_sin  \
# 0         0.0         1.0  ...           0.0           1.0        0.0
#
#    dayly_cos  dayly_2_sin  dayly_2_cos  scaled_hours  scaled_hours_squared  \
# 0        1.0          0.0          1.0           0.0                   0.0
#
#    scaled_hours_cubic  usage_trend_removed
# 0                 0.0         -1472.100301
#
# [1 rows x 26 columns]

# %%
columns_x = []
for column in df_train.columns:
    if column.endswith('sin') or column.endswith('cos'):
        columns_x.append(column)

# %%
X = df_train[columns_x].values
y = df_train['usage_trend_removed'].values

period_model = LinearRegression().fit(X,y)

# %%
period_model.coef_
# Out:
# array([ 3822.75713454,  6415.70887752,  2830.03767946,  2983.67559318,
#         -150.44983634,  -636.28208157,   762.90873997,  1112.36053659,
#         -632.34873725,  -230.61807329, -5891.27455544, -4097.12080555,
#        -1057.06125805,  -704.06067565])

# %%
from sklearn.metrics import r2_score

# Plot the prediction for the train data
#df_valid = df_valid.reset_index(drop=True)
samples_X = df_train.loc[:, columns_x].values
samples_Y = df_train.loc[:, 'usage_trend_removed'].values
train_pred = period_model.predict(samples_X)

plt.subplots(figsize=(30,15))
plt.plot(train_pred)
_ = plt.plot(samples_Y)

# r2_score(samples_Y, pred_Y)

# %%
# plot the prediction for the validation data.

df_valid = df_valid.reset_index(drop=True)
samples_X = df_valid.loc[:100, columns_x].values
samples_Y = df_valid.loc[:100, 'usage_trend_removed'].values
pred_Y = period_model.predict(samples_X)

plt.subplots(figsize=(30,15))
plt.plot(pred_Y)
plt.plot(samples_Y)

print('r2_score: {}'.format(r2_score(samples_Y, pred_Y)))
# Out:
# r2_score: 0.7224138831072557

# %% [markdown]
# Try auto correlation and partial autocorrelation in the residual to make new discovery.

# %%
df_train.loc[:, 'pred'] = train_pred.reshape(-1)

df_train.loc[:, 'residual'] = df_train.loc[:, 'usage_trend_removed'] - df_train.loc[:, 'pred']
# Out:
# /Users/minjielu/anaconda3/envs/Renaissance/lib/python3.5/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

_ = plot_acf(df_train['residual'],lags=300)

# %%
_ = plot_pacf(df_train['residual'],lags=100)

# %%
residual_fft = np.absolute(np.fft.fft(df_train['residual']))
plt.plot(residual_fft)
_ = plt.xlim([2900,3100])

# %%
len(df_train)
# Out:
# 23175

# %%
23175/2/3.14*0.95
# Out:
# 3505.7722929936303

# %%
np.arctan(1.4)
# Out:
# 0.9505468408120751

# %%
23175/3030/24
# Out:
# 0.3186881188118812

# %%
X = np.sin(np.arange(0,30,0.1))
_ = plot_pacf(X)
plt.xlim([-1,70])
# Out:
# (-1, 70)

# %%
_ = plot_acf(X)

# %%
from statsmodels.tsa.stattools import ccf

# %%
ccf_1 = ccf(df_train['residual'], df_joined.iloc[:train_index]['T_Houston'])

# %%
plt.plot(ccf_1)
plt.xlim([-1,300])
plt.ylim([-0.2,0.2])
# Out:
# (-0.2, 0.2)

# %%
5000/24
# Out:
# 208.33333333333334

# %%
df_joined.head(1)
# Out:
#                  datetime  usage  time  month  weekday  year  day  T_Houston  \
# 36934 2015-07-01 01:05:00  37456     1      7        2  2015    1       71.0
#
#        T_san_antonio  T_dallas
# 36934           77.0      73.0

# %%
df_train.head(1)
# Out:
#              datetime  usage  time  month  weekday  year  day  hours  \
# 0 2015-07-01 01:05:00  37456     1      7        2  2015    1    0.0
#
#    yearly_sin  yearly_cos  ...  dayly_sin  dayly_cos  dayly_2_sin  \
# 0         0.0         1.0  ...        0.0        1.0          0.0
#
#    dayly_2_cos  scaled_hours  scaled_hours_squared  scaled_hours_cubic  \
# 0          1.0           0.0                   0.0                 0.0
#
#    usage_trend_removed     residual        pred
# 0         -1472.100301 -5889.020771  4416.92047
#
# [1 rows x 28 columns]
